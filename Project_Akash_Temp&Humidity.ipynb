# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from math import sqrt
from numpy import concatenate, random
from matplotlib import pyplot as plt
from pandas import read_csv, DataFrame, to_datetime, concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, LSTM

random.seed(7)

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# Read dataset
file_path = '/content/drive/MyDrive/Temp&Humidity/DataSet Sensor Kel2.txt'  # Replace with your file path
dataset = read_csv(file_path, parse_dates={'datetime': ['Tanggal', 'Waktu']}, dayfirst=True, infer_datetime_format=True)
dataset['datetime'] = to_datetime(dataset['datetime'], format='%d/%m/%Y %H.%M.%S')
dataset['Bulan'] = dataset['datetime'].dt.month

# Select features for temperature and humidity
features_to_predict_temperature = ['Suhu (C)']
features_to_predict_humidity = ['Kelembaban']

# Normalize features using MinMaxScaler
scaler_temperature = MinMaxScaler(feature_range=(0, 1))
scaler_humidity = MinMaxScaler(feature_range=(0, 1))

scaled_values_temperature = scaler_temperature.fit_transform(dataset[features_to_predict_temperature])
scaled_values_humidity = scaler_humidity.fit_transform(dataset[features_to_predict_humidity])

# Prepare temperature dataset
reframed_temperature = series_to_supervised(scaled_values_temperature, 1, 1)
reframed_temperature.drop(reframed_temperature.columns[2:], axis=1, inplace=True)
values_temperature = reframed_temperature.values
n_train_temperature = int(len(dataset) * 0.75)
train_temperature = values_temperature[:n_train_temperature, :]
test_temperature = values_temperature[n_train_temperature:, :]
train_x_temperature, train_y_temperature = train_temperature[:, :-1], train_temperature[:, -1]
test_x_temperature, test_y_temperature = test_temperature[:, :-1], test_temperature[:, -1]
train_x_temperature = train_x_temperature.reshape((train_x_temperature.shape[0], 1, train_x_temperature.shape[1]))
test_x_temperature = test_x_temperature.reshape((test_x_temperature.shape[0], 1, test_x_temperature.shape[1]))

# Design and train LSTM model for temperature
model_temperature = Sequential()
model_temperature.add(LSTM(150, input_shape=(train_x_temperature.shape[1], train_x_temperature.shape[2])))
model_temperature.add(Dense(units=1))
model_temperature.compile(loss='mae', optimizer='adam')
history_temperature = model_temperature.fit(train_x_temperature, train_y_temperature, epochs=100, batch_size=32,
                                           validation_data=(test_x_temperature, test_y_temperature), verbose=1, shuffle=False)

# Make predictions for temperature
yhat_train_temperature = model_temperature.predict(train_x_temperature)
train_x_temperature = train_x_temperature.reshape((train_x_temperature.shape[0], train_x_temperature.shape[2]))
inv_yhat_train_temperature = scaler_temperature.inverse_transform(
    concatenate((yhat_train_temperature, train_x_temperature[:, 1:]), axis=1))
inv_yhat_train_temperature = inv_yhat_train_temperature[:, 0]
train_y_temperature = train_y_temperature.reshape((len(train_y_temperature), 1))
inv_y_train_temperature = scaler_temperature.inverse_transform(
    concatenate((train_y_temperature, train_x_temperature[:, 1:]), axis=1))
inv_y_train_temperature = inv_y_train_temperature[:, 0]

yhat_test_temperature = model_temperature.predict(test_x_temperature)
test_x_temperature = test_x_temperature.reshape((test_x_temperature.shape[0], test_x_temperature.shape[2]))
inv_yhat_test_temperature = scaler_temperature.inverse_transform(
    concatenate((yhat_test_temperature, test_x_temperature[:, 1:]), axis=1))
inv_yhat_test_temperature = inv_yhat_test_temperature[:, 0]
test_y_temperature = test_y_temperature.reshape((len(test_y_temperature), 1))
inv_y_test_temperature = scaler_temperature.inverse_transform(
    concatenate((test_y_temperature, test_x_temperature[:, 1:]), axis=1))
inv_y_test_temperature = inv_y_test_temperature[:, 0]

# Prepare humidity dataset
reframed_humidity = series_to_supervised(scaled_values_humidity, 1, 1)
reframed_humidity.drop(reframed_humidity.columns[2:], axis=1, inplace=True)
values_humidity = reframed_humidity.values
n_train_humidity = int(len(dataset) * 0.75)
train_humidity = values_humidity[:n_train_humidity, :]
test_humidity = values_humidity[n_train_humidity:, :]
train_x_humidity, train_y_humidity = train_humidity[:, :-1], train_humidity[:, -1]
test_x_humidity, test_y_humidity = test_humidity[:, :-1], test_humidity[:, -1]
train_x_humidity = train_x_humidity.reshape((train_x_humidity.shape[0], 1, train_x_humidity.shape[1]))
test_x_humidity = test_x_humidity.reshape((test_x_humidity.shape[0], 1, test_x_humidity.shape[1]))

# Design and train LSTM model for humidity
model_humidity = Sequential()
model_humidity.add(LSTM(150, input_shape=(train_x_humidity.shape[1], train_x_humidity.shape[2])))
model_humidity.add(Dense(units=1))
model_humidity.compile(loss='mae', optimizer='adam')
history_humidity = model_humidity.fit(train_x_humidity, train_y_humidity, epochs=100, batch_size=32,
                                      validation_data=(test_x_humidity, test_y_humidity), verbose=1, shuffle=False)

# Make predictions for humidity
yhat_train_humidity = model_humidity.predict(train_x_humidity)
train_x_humidity = train_x_humidity.reshape((train_x_humidity.shape[0], train_x_humidity.shape[2]))
inv_yhat_train_humidity = scaler_humidity.inverse_transform(
    concatenate((yhat_train_humidity, train_x_humidity[:, 1:]), axis=1))
inv_yhat_train_humidity = inv_yhat_train_humidity[:, 0]
train_y_humidity = train_y_humidity.reshape((len(train_y_humidity), 1))
inv_y_train_humidity = scaler_humidity.inverse_transform(
    concatenate((train_y_humidity, train_x_humidity[:, 1:]), axis=1))
inv_y_train_humidity = inv_y_train_humidity[:, 0]

yhat_test_humidity = model_humidity.predict(test_x_humidity)
test_x_humidity = test_x_humidity.reshape((test_x_humidity.shape[0], test_x_humidity.shape[2]))
inv_yhat_test_humidity = scaler_humidity.inverse_transform(
    concatenate((yhat_test_humidity, test_x_humidity[:, 1:]), axis=1))
inv_yhat_test_humidity = inv_yhat_test_humidity[:, 0]
test_y_humidity = test_y_humidity.reshape((len(test_y_humidity), 1))
inv_y_test_humidity = scaler_humidity.inverse_transform(
    concatenate((test_y_humidity, test_x_humidity[:, 1:]), axis=1))
inv_y_test_humidity = inv_y_test_humidity[:, 0]

# Plot Model Loss for temperature
plt.figure(figsize=(10, 5))
plt.plot(history_temperature.history['loss'], label='Temperature Training Loss')
plt.plot(history_temperature.history['val_loss'], label='Temperature Validation Loss')
plt.title('Temperature Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot Model Loss for humidity
plt.figure(figsize=(10, 5))
plt.plot(history_humidity.history['loss'], label='Humidity Training Loss')
plt.plot(history_humidity.history['val_loss'], label='Humidity Validation Loss')
plt.title('Humidity Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Calculate RMSE for temperature and humidity
rmse_train_temperature = sqrt(mean_squared_error(inv_y_train_temperature, inv_yhat_train_temperature))
print('Temperature Train RMSE: %.3f' % rmse_train_temperature)

rmse_test_temperature = sqrt(mean_squared_error(inv_y_test_temperature, inv_yhat_test_temperature))
print('Temperature Test RMSE: %.3f' % rmse_test_temperature)

rmse_train_humidity = sqrt(mean_squared_error(inv_y_train_humidity, inv_yhat_train_humidity))
print('Humidity Train RMSE: %.3f' % rmse_train_humidity)

rmse_test_humidity = sqrt(mean_squared_error(inv_y_test_humidity, inv_yhat_test_humidity))
print('Humidity Test RMSE: %.3f' % rmse_test_humidity)

# Plot the results for temperature
x0_temperature = list(range(len(train_y_temperature)))
x1_temperature = list(range(len(train_y_temperature), len(train_y_temperature) + len(test_y_temperature)))

fig_temperature, (ax1_temperature, ax2_temperature) = plt.subplots(2, 1, sharex=True, figsize=(10, 8))

# Plot for Suhu (C)
ax1_temperature.plot(dataset['datetime'], dataset['Suhu (C)'], 'b', label='Actual Temp (C)')
ax1_temperature.plot(dataset['datetime'].iloc[x1_temperature], inv_yhat_test_temperature, 'r', label='Predicted Temp (C)')
ax1_temperature.set_ylabel('Temp (C)')
ax1_temperature.set_xlabel('Date')
ax1_temperature.set_title('Predicted Temp (C)')
ax1_temperature.legend()

# Plot for Kelembaban
ax2_temperature.plot(dataset['datetime'], dataset['Kelembaban'], 'b', label='Actual Humidity')
ax2_temperature.plot(dataset['datetime'].iloc[x1_temperature], inv_yhat_test_humidity, 'r', label='Predicted Humidity')
ax2_temperature.set_ylabel('Humidity')
ax2_temperature.set_xlabel('Date')
ax2_temperature.set_title('Predicted Humidity')
ax2_temperature.legend()

ax1_temperature.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d-%m'))
ax2_temperature.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d-%m'))

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-2-7efb5edccb3d>:39: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   dataset = read_csv(file_path, parse_dates={'datetime': ['Tanggal', 'Waktu']}, dayfirst=True, infer_datetime_format=True)
# <ipython-input-2-7efb5edccb3d>:39: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dataset = read_csv(file_path, parse_dates={'datetime': ['Tanggal', 'Waktu']}, dayfirst=True, infer_datetime_format=True)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.3540 - val_loss: 0.0111
# Epoch 2/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0204 - val_loss: 0.0140
# Epoch 3/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0215 - val_loss: 0.0133
# Epoch 4/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0196 - val_loss: 0.0098
# Epoch 5/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0186 - val_loss: 0.0121
# Epoch 6/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0180 - val_loss: 0.0096
# Epoch 7/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0177 - val_loss: 0.0113
# Epoch 8/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0191 - val_loss: 0.0109
# Epoch 9/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0175 - val_loss: 0.0120
# Epoch 10/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0168 - val_loss: 0.0097
# Epoch 11/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0162 - val_loss: 0.0110
# Epoch 12/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0163 - val_loss: 0.0145
# Epoch 13/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0164 - val_loss: 0.0105
# Epoch 14/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0159 - val_loss: 0.0087
# Epoch 15/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0160 - val_loss: 0.0079
# Epoch 16/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0149 - val_loss: 0.0083
# Epoch 17/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0157 - val_loss: 0.0125
# Epoch 18/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0155 - val_loss: 0.0092
# Epoch 19/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0156 - val_loss: 0.0072
# Epoch 20/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0151 - val_loss: 0.0116
# Epoch 21/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0152 - val_loss: 0.0087
# Epoch 22/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0144 - val_loss: 0.0066
# Epoch 23/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0144 - val_loss: 0.0086
# Epoch 24/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0146 - val_loss: 0.0085
# Epoch 25/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0145 - val_loss: 0.0091
# Epoch 26/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0138 - val_loss: 0.0073
# Epoch 27/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0131 - val_loss: 0.0081
# Epoch 28/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0132 - val_loss: 0.0104
# Epoch 29/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0125 - val_loss: 0.0075
# Epoch 30/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0121 - val_loss: 0.0065
# Epoch 31/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0114 - val_loss: 0.0073
# Epoch 32/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0128 - val_loss: 0.0051
# Epoch 33/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0112 - val_loss: 0.0060
# Epoch 34/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0101 - val_loss: 0.0059
# Epoch 35/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0099 - val_loss: 0.0067
# Epoch 36/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0091 - val_loss: 0.0080
# Epoch 37/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0096 - val_loss: 0.0052
# Epoch 38/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0097 - val_loss: 0.0059
# Epoch 39/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0087 - val_loss: 0.0045
# Epoch 40/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0090 - val_loss: 0.0073
# Epoch 41/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0090 - val_loss: 0.0045
# Epoch 42/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0090 - val_loss: 0.0047
# Epoch 43/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0080 - val_loss: 0.0051
# Epoch 44/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0082 - val_loss: 0.0042
# Epoch 45/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0079 - val_loss: 0.0040
# Epoch 46/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0075 - val_loss: 0.0050
# Epoch 47/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0079 - val_loss: 0.0050
# Epoch 48/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0075 - val_loss: 0.0053
# Epoch 49/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0079 - val_loss: 0.0046
# Epoch 50/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0071 - val_loss: 0.0056
# Epoch 51/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0072 - val_loss: 0.0036
# Epoch 52/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0070 - val_loss: 0.0037
# Epoch 53/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0067 - val_loss: 0.0035
# Epoch 54/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0072 - val_loss: 0.0039
# Epoch 55/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0061 - val_loss: 0.0051
# Epoch 56/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0068 - val_loss: 0.0035
# Epoch 57/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0062 - val_loss: 0.0036
# Epoch 58/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0065 - val_loss: 0.0032
# Epoch 59/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0064 - val_loss: 0.0053
# Epoch 60/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 61/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0065 - val_loss: 0.0080
# Epoch 62/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0060 - val_loss: 0.0046
# Epoch 63/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 64/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0061 - val_loss: 0.0050
# Epoch 65/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 66/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0055 - val_loss: 0.0041
# Epoch 67/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0058 - val_loss: 0.0072
# Epoch 68/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0059 - val_loss: 0.0057
# Epoch 69/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0049 - val_loss: 0.0033
# Epoch 70/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0053 - val_loss: 0.0030
# Epoch 71/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0055 - val_loss: 0.0029
# Epoch 72/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0051 - val_loss: 0.0027
# Epoch 73/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0050 - val_loss: 0.0045
# Epoch 74/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0055 - val_loss: 0.0030
# Epoch 75/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0053 - val_loss: 0.0029
# Epoch 76/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0059 - val_loss: 0.0041
# Epoch 77/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0056 - val_loss: 0.0059
# Epoch 78/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 79/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0051 - val_loss: 0.0032
# Epoch 80/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0058 - val_loss: 0.0044
# Epoch 81/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0053 - val_loss: 0.0057
# Epoch 82/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0058 - val_loss: 0.0043
# Epoch 83/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - val_loss: 0.0036
# Epoch 84/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 85/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0052 - val_loss: 0.0039
# Epoch 86/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0052 - val_loss: 0.0066
# Epoch 87/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0063 - val_loss: 0.0030
# Epoch 88/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0049 - val_loss: 0.0066
# Epoch 89/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0059 - val_loss: 0.0026
# Epoch 90/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0052 - val_loss: 0.0064
# Epoch 91/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0051 - val_loss: 0.0027
# Epoch 92/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0057 - val_loss: 0.0037
# Epoch 93/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0056 - val_loss: 0.0044
# Epoch 94/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0062 - val_loss: 0.0031
# Epoch 95/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 96/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0050 - val_loss: 0.0033
# Epoch 97/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0052 - val_loss: 0.0059
# Epoch 98/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0051 - val_loss: 0.0040
# Epoch 99/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0052 - val_loss: 0.0028
# Epoch 100/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0056 - val_loss: 0.0053
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.3202 - val_loss: 0.0277
# Epoch 2/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0416 - val_loss: 0.0297
# Epoch 3/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0390 - val_loss: 0.0222
# Epoch 4/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0357 - val_loss: 0.0212
# Epoch 5/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0319 - val_loss: 0.0197
# Epoch 6/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0299 - val_loss: 0.0164
# Epoch 7/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0290 - val_loss: 0.0134
# Epoch 8/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0266 - val_loss: 0.0117
# Epoch 9/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0246 - val_loss: 0.0105
# Epoch 10/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0207 - val_loss: 0.0090
# Epoch 11/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0183 - val_loss: 0.0078
# Epoch 12/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0160 - val_loss: 0.0095
# Epoch 13/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0143 - val_loss: 0.0077
# Epoch 14/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0130 - val_loss: 0.0051
# Epoch 15/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0113 - val_loss: 0.0062
# Epoch 16/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0106 - val_loss: 0.0040
# Epoch 17/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0084 - val_loss: 0.0035
# Epoch 18/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0086 - val_loss: 0.0054
# Epoch 19/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0079 - val_loss: 0.0038
# Epoch 20/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0083 - val_loss: 0.0039
# Epoch 21/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0083 - val_loss: 0.0056
# Epoch 22/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0096 - val_loss: 0.0053
# Epoch 23/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0082 - val_loss: 0.0039
# Epoch 24/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0082 - val_loss: 0.0058
# Epoch 25/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0078 - val_loss: 0.0045
# Epoch 26/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0085 - val_loss: 0.0038
# Epoch 27/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0088 - val_loss: 0.0049
# Epoch 28/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0082 - val_loss: 0.0040
# Epoch 29/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0084 - val_loss: 0.0061
# Epoch 30/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0088 - val_loss: 0.0044
# Epoch 31/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0095 - val_loss: 0.0045
# Epoch 32/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 33/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0086 - val_loss: 0.0052
# Epoch 34/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0106 - val_loss: 0.0051
# Epoch 35/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0079 - val_loss: 0.0032
# Epoch 36/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0078 - val_loss: 0.0053
# Epoch 37/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0081 - val_loss: 0.0049
# Epoch 38/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0079 - val_loss: 0.0035
# Epoch 39/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0079 - val_loss: 0.0086
# Epoch 40/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0089 - val_loss: 0.0056
# Epoch 41/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0100 - val_loss: 0.0039
# Epoch 42/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0084 - val_loss: 0.0061
# Epoch 43/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0086 - val_loss: 0.0055
# Epoch 44/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0089 - val_loss: 0.0072
# Epoch 45/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0083 - val_loss: 0.0076
# Epoch 46/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0091 - val_loss: 0.0082
# Epoch 47/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0081 - val_loss: 0.0056
# Epoch 48/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0083 - val_loss: 0.0044
# Epoch 49/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0083 - val_loss: 0.0040
# Epoch 50/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0079 - val_loss: 0.0034
# Epoch 51/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0078 - val_loss: 0.0086
# Epoch 52/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0083 - val_loss: 0.0043
# Epoch 53/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0081 - val_loss: 0.0045
# Epoch 54/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0088 - val_loss: 0.0040
# Epoch 55/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0082 - val_loss: 0.0034
# Epoch 56/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0080 - val_loss: 0.0037
# Epoch 57/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0087 - val_loss: 0.0060
# Epoch 58/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0092 - val_loss: 0.0044
# Epoch 59/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0082 - val_loss: 0.0059
# Epoch 60/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0086 - val_loss: 0.0068
# Epoch 61/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0078 - val_loss: 0.0065
# Epoch 62/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0085 - val_loss: 0.0056
# Epoch 63/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0080 - val_loss: 0.0045
# Epoch 64/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0080 - val_loss: 0.0056
# Epoch 65/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0077 - val_loss: 0.0040
# Epoch 66/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0081 - val_loss: 0.0039
# Epoch 67/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0084 - val_loss: 0.0052
# Epoch 68/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0083 - val_loss: 0.0065
# Epoch 69/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0084 - val_loss: 0.0034
# Epoch 70/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0079 - val_loss: 0.0061
# Epoch 71/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0078 - val_loss: 0.0032
# Epoch 72/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0078 - val_loss: 0.0035
# Epoch 73/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0080 - val_loss: 0.0035
# Epoch 74/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0083 - val_loss: 0.0034
# Epoch 75/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0083 - val_loss: 0.0037
# Epoch 76/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0079 - val_loss: 0.0033
# Epoch 77/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0078 - val_loss: 0.0034
# Epoch 78/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0076 - val_loss: 0.0055
# Epoch 79/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0081 - val_loss: 0.0054
# Epoch 80/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0080 - val_loss: 0.0035
# Epoch 81/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0078 - val_loss: 0.0049
# Epoch 82/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0086 - val_loss: 0.0095
# Epoch 83/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0088 - val_loss: 0.0037
# Epoch 84/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0085 - val_loss: 0.0070
# Epoch 85/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0079 - val_loss: 0.0061
# Epoch 86/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0084 - val_loss: 0.0034
# Epoch 87/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0075 - val_loss: 0.0044
# Epoch 88/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0079 - val_loss: 0.0040
# Epoch 89/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0083 - val_loss: 0.0044
# Epoch 90/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0082 - val_loss: 0.0061
# Epoch 91/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0080 - val_loss: 0.0035
# Epoch 92/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0082 - val_loss: 0.0035
# Epoch 93/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0076 - val_loss: 0.0037
# Epoch 94/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0079 - val_loss: 0.0054
# Epoch 95/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0080 - val_loss: 0.0072
# Epoch 96/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0082 - val_loss: 0.0054
# Epoch 97/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0085 - val_loss: 0.0054
# Epoch 98/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0096 - val_loss: 0.0048
# Epoch 99/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0080 - val_loss: 0.0058
# Epoch 100/100
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0088 - val_loss: 0.0032
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Temperature Train RMSE: 0.546
# Temperature Test RMSE: 0.266
# Humidity Train RMSE: 1.525
# Humidity Test RMSE: 0.683
